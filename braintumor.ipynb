# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreenithi15/Educational-Chatbot/blob/master/braintumor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/jonathanrao99/Brain-Tumor-Detection-using-Deep-Learning.git
# %cd Brain-Tumor-Detection-using-Deep-Learning/
# !pip install -q tensorflow pandas numpy matplotlib scikit-learn
# !ls
# %cd /content/Brain-Tumor-Detection-using-Deep-Learning
# !unzip -q "Brain Scans.zip"
# Out:
# fatal: destination path 'Brain-Tumor-Detection-using-Deep-Learning' already exists and is not an empty directory.
# /content/Brain-Tumor-Detection-using-Deep-Learning/Brain-Tumor-Detection-using-Deep-Learning
# 'Brain Scans.zip'  'Brain Tumor.csv'   Brain_tumor.ipynb   LICENSE   README.md
# /content/Brain-Tumor-Detection-using-Deep-Learning

# %%
import os
print(os.listdir())
# Out:
# ['.git', 'README.md', 'LICENSE', 'Brain_tumor.ipynb', 'Brain Tumor.csv', 'Brain Scans', 'Brain Scans.zip', 'Brain-Tumor-Detection-using-Deep-Learning']

# %%
# %cd /content
# Out:
# /content

# %%
# !rm -rf Brain-Tumor-Detection-using-Deep-Learning

# %%
# !git clone https://github.com/jonathanrao99/Brain-Tumor-Detection-using-Deep-Learning.git
# Out:
# Cloning into 'Brain-Tumor-Detection-using-Deep-Learning'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 3), reused 3 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 13.33 MiB | 40.50 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# %cd Brain-Tumor-Detection-using-Deep-Learning
# Out:
# /content/Brain-Tumor-Detection-using-Deep-Learning

# %%
# !ls
# Out:
# 'Brain Scans.zip'  'Brain Tumor.csv'   Brain_tumor.ipynb   LICENSE   README.md

# %%
# !unzip -q "Brain Scans.zip"
# Out:
# unzip:  cannot find or open Brain Scans.zip, Brain Scans.zip.zip or Brain Scans.zip.ZIP.

# %%
# !pip install -q tensorflow pandas numpy matplotlib seaborn scikit-learn pillow

# %%
mv "Brain Scans.zip" Brain_Scans.zip
# Out:
# mv: cannot stat 'Brain Scans.zip': No such file or directory

# %%
# %cd /content/Brain-Tumor-Detection-using-Deep-Learning
# Out:
# [Errno 2] No such file or directory: '/content/Brain-Tumor-Detection-using-Deep-Learning'
# /content

# %%
# !ls /content
# Out:
# sample_data

# %%
# !rm -rf /content/Brain*

# %%
# %cd /content
# !git clone https://github.com/jonathanrao99/Brain-Tumor-Detection-using-Deep-Learning.git
# Out:
# /content
# Cloning into 'Brain-Tumor-Detection-using-Deep-Learning'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 3), reused 3 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 13.33 MiB | 41.49 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# %cd /content/Brain-Tumor-Detection-using-Deep-Learning
# Out:
# /content/Brain-Tumor-Detection-using-Deep-Learning

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content/Brain-Tumor-Detection-using-Deep-Learning
# ['.git', 'README.md', 'LICENSE', 'Brain_tumor.ipynb', 'Brain Tumor.csv', 'Brain Scans.zip']

# %%
# !unzip "Brain Scans.zip"
# Out:
# Archive:  Brain Scans.zip
#    creating: Brain Scans/Brain Tumor/
#   inflating: Brain Scans/Brain Tumor/Image1.jpg
#   inflating: Brain Scans/Brain Tumor/Image10.jpg
#   inflating: Brain Scans/Brain Tumor/Image100.jpg
#   inflating: Brain Scans/Brain Tumor/Image1000.jpg
#   inflating: Brain Scans/Brain Tumor/Image1001.jpg
#   inflating: Brain Scans/Brain Tumor/Image1002.jpg
#   inflating: Brain Scans/Brain Tumor/Image1003.jpg
#   inflating: Brain Scans/Brain Tumor/Image1004.jpg
#   inflating: Brain Scans/Brain Tumor/Image1005.jpg
#   inflating: Brain Scans/Brain Tumor/Image1006.jpg
#   inflating: Brain Scans/Brain Tumor/Image1007.jpg
#   inflating: Brain Scans/Brain Tumor/Image1008.jpg
#   inflating: Brain Scans/Brain Tumor/Image1009.jpg
#   inflating: Brain Scans/Brain Tumor/Image101.jpg
#   inflating: Brain Scans/Brain Tumor/Image1010.jpg
#   inflating: Brain Scans/Brain Tumor/Image1011.jpg
#   inflating: Brain Scans/Brain Tumor/Image1012.jpg
# ...

# %%
# !ls
# Out:
# 'Brain Scans'	   'Brain Tumor.csv'    LICENSE
# 'Brain Scans.zip'   Brain_tumor.ipynb   README.md

# %%
# !pip install -q tensorflow pandas numpy matplotlib seaborn scikit-learn pillow

# %%
# !ls /content
# Out:
# Brain-Tumor-Detection-using-Deep-Learning  sample_data
